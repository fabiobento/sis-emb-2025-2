# %% [markdown]
# # OCR com Python e Tesseract

# %% [markdown]
# # Reconhecimento de texto em imagens

# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiobento/ocr-sis-emb-2024-2/blob/main/1-OCR_com_Python_e_Tesseract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Instalando o Tesseract
#
# Documentação: https://pypi.org/project/pytesseract/

# %%
try:
    import google.colab
    IN_COLAB = True
    print("Executando no Google Colab")
except ImportError:
    IN_COLAB = False
    print("Não executando no Google Colab")
# Out:
# Não executando no Google Colab

# %%
if IN_COLAB:
    # Baixar imagens para o laboratório.
    # !wget https://github.com/fabiobento/ocr-sis-emb-2024-2/raw/refs/heads/main/imagens.zip
    # !unzip -n -q imagens.zip

    # Baixar fontes para o laboratório
    # !wget https://github.com/fabiobento/ocr-sis-emb-2024-2/raw/refs/heads/main/fontes.zip
    # !unzip -n -q fontes.zip

# %%
# %pip install Pillow
# Após executar, clique no botão [Restart Runtime] que vai aparecer no output dessa célula, logo abaixo. Em seguida, pode continuar executando normalmente o restante do código
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (10.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !sudo apt update
# !sudo apt install -y tesseract-ocr
# %pip install pytesseract
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1581 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2086 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1288 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]3m
# Get:8 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 Packages [266 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 Packages [17.5 MB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5878 kB]3m
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [60.9 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3479 kB]33m
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 Packages [1792 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/restricted amd64 Packages [164 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6148 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3847 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1594 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.2 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Fetched 44.9 MB in 4s (11.0 MB/s)33m
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 129 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libarchive13 libgif7 liblept5 libopenjp2-7 libtesseract4 libwebpmux3
#   tesseract-ocr-eng tesseract-ocr-osd
# Suggested packages:
#   lrzip
# The following NEW packages will be installed:
#   libarchive13 libgif7 liblept5 libopenjp2-7 libtesseract4 libwebpmux3
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 9 newly installed, 0 to remove and 129 not upgraded.
# Need to get 7812 kB of archives.
# After this operation, 23.2 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libarchive13 amd64 3.6.0-1ubuntu1.5 [368 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgif7 amd64 5.1.9-2ubuntu0.1 [33.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libopenjp2-7 amd64 2.4.0-6ubuntu0.4 [158 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwebpmux3 amd64 1.2.2-2ubuntu0.22.04.2 [20.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblept5 amd64 1.82.0-3build1 [1107 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtesseract4 amd64 4.1.1-2.1build1 [1308 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1591 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2990 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 7812 kB in 3s (2649 kB/s)
#
# 78Selecting previously unselected package libarchive13:amd64.
# (Reading database ... 21753 files and directories currently installed.)
# Preparing to unpack .../0-libarchive13_3.6.0-1ubuntu1.5_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  3%] [#.........................................................] 8Unpacking libarchive13:amd64 (3.6.0-1ubuntu1.5) ...
# 7Progress: [  5%] [###.......................................................] 8Selecting previously unselected package libgif7:amd64.
# Preparing to unpack .../1-libgif7_5.1.9-2ubuntu0.1_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking libgif7:amd64 (5.1.9-2ubuntu0.1) ...
# 7Progress: [ 11%] [######....................................................] 8Selecting previously unselected package libopenjp2-7:amd64.
# Preparing to unpack .../2-libopenjp2-7_2.4.0-6ubuntu0.4_amd64.deb ...
# 7Progress: [ 14%] [#######...................................................] 8Unpacking libopenjp2-7:amd64 (2.4.0-6ubuntu0.4) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libwebpmux3:amd64.
# Preparing to unpack .../3-libwebpmux3_1.2.2-2ubuntu0.22.04.2_amd64.deb ...
# 7Progress: [ 19%] [##########................................................] 8Unpacking libwebpmux3:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package liblept5:amd64.
# Preparing to unpack .../4-liblept5_1.82.0-3build1_amd64.deb ...
# 7Progress: [ 24%] [##############............................................] 8Unpacking liblept5:amd64 (1.82.0-3build1) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libtesseract4:amd64.
# Preparing to unpack .../5-libtesseract4_4.1.1-2.1build1_amd64.deb ...
# 7Progress: [ 30%] [#################.........................................] 8Unpacking libtesseract4:amd64 (4.1.1-2.1build1) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package tesseract-ocr-eng.
# Preparing to unpack .../6-tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# 7Progress: [ 38%] [#####################.....................................] 8Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../7-tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# 7Progress: [ 43%] [#########################.................................] 8Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../8-tesseract-ocr_4.1.1-2.1build1_amd64.deb ...
# 7Progress: [ 46%] [##########################................................] 8Unpacking tesseract-ocr (4.1.1-2.1build1) ...
# 7Progress: [ 49%] [############################..............................] 8Setting up libarchive13:amd64 (3.6.0-1ubuntu1.5) ...
# 7Progress: [ 51%] [#############################.............................] 87Progress: [ 54%] [###############################...........................] 8Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# 7Progress: [ 57%] [################################..........................] 87Progress: [ 59%] [##################################........................] 8Setting up libgif7:amd64 (5.1.9-2ubuntu0.1) ...
# 7Progress: [ 62%] [####################################......................] 87Progress: [ 65%] [#####################################.....................] 8Setting up libopenjp2-7:amd64 (2.4.0-6ubuntu0.4) ...
# 7Progress: [ 68%] [#######################################...................] 87Progress: [ 70%] [########################################..................] 8Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# 7Progress: [ 73%] [##########################################................] 87Progress: [ 76%] [###########################################...............] 8Setting up libwebpmux3:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# 7Progress: [ 78%] [#############################################.............] 87Progress: [ 81%] [###############################################...........] 8Setting up liblept5:amd64 (1.82.0-3build1) ...
# 7Progress: [ 84%] [################################################..........] 87Progress: [ 86%] [##################################################........] 8Setting up libtesseract4:amd64 (4.1.1-2.1build1) ...
# 7Progress: [ 89%] [###################################################.......] 87Progress: [ 92%] [#####################################################.....] 8Setting up tesseract-ocr (4.1.1-2.1build1) ...
# 7Progress: [ 95%] [######################################################....] 87Progress: [ 97%] [########################################################..] 8Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
#
# 78Defaulting to user installation because normal site-packages is not writeable
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (10.4.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
#   WARNING: The script pytesseract is installed in '/home/fabio/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed pytesseract-0.3.13
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importando as bibliotecas

# %%
import pytesseract
import numpy as np
import cv2 # OpenCV
import matplotlib.pyplot as plt
if IN_COLAB:
    from google.colab.patches import cv2_imshow

# %%
# Definir função para exibição de imagens
def imshow(imagem):
    if IN_COLAB:
        cv2_imshow(imagem)
    else:
        # Exibir a imagem com matplotlib
        if len(imagem.shape) == 2:  # Se a imagem tiver apenas 2 dimensões (níveis de cinza)
            plt.imshow(imagem, cmap='gray')
            plt.axis('off')  # Oculta os eixos
            plt.show()               
        else:
            plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))        
            plt.axis('off')  # Oculta os eixos
            plt.show()

# %% [markdown]
# ## Leitura da imagem

# %%
img = cv2.imread('./Imagens/teste01.jpg')
imshow(img) # BGR (RGB)

# %%
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imshow(rgb)

# %%
texto = pytesseract.image_to_string(rgb)

# %%
print(texto)
# Out:
# testando o
# OCR...

# %% [markdown]
# ## Suporte para caracteres e símbolos de outros idiomas

# %%
img = cv2.imread('./Imagens/teste02.jpg')
imshow(img)

# %%
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imshow(rgb)

# %%
texto = pytesseract.image_to_string(rgb)
print(texto) # resumé, fiancé, déjà vu

# %%
# !tesseract --list-langs

# %%
# !apt-get install tesseract-ocr-por

# %%
# !tesseract --list-langs

# %% [markdown]
# Baixar  e salvar pacotre de idiomas
# Portanto, o link final ficou: https://github.com/tesseract-ocr/tessdata/blob/main/por.traineddata?raw=true (segue abaixo o comando completo)

# %%
# !mkdir tessdata

# %%
# !wget -O ./tessdata/por.traineddata https://github.com/tesseract-ocr/tessdata/blob/main/por.traineddata?raw=true

# %%
config_tesseract = '--tessdata-dir tessdata'
texto = pytesseract.image_to_string(rgb, lang='por', config=config_tesseract)
print(texto)

# %%
# !wget -O ./tessdata/eng.traineddata https://github.com/tesseract-ocr/tessdata/blob/main/eng.traineddata?raw=true

# %%
# !ls tessdata/

# %% [markdown]
# ## Parâmetros

# %% [markdown]
# ### Page segmentation modes (PSM)

# %%
# !tesseract --help-psm

# %%
img = cv2.imread('./Imagens/trecho-livro.jpg')
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imshow(rgb)

# %%
config_tesseract = '--tessdata-dir tessdata --psm 6'
texto = pytesseract.image_to_string(rgb, lang='por', config=config_tesseract)
print(texto)

# %%
config_tesseract = '--tessdata-dir tessdata'
texto = pytesseract.image_to_string(rgb, lang='por', config=config_tesseract)
print(texto)

# %%
config_tesseract = '--tessdata-dir tessdata --psm 7'
texto = pytesseract.image_to_string(rgb, lang='por', config=config_tesseract)
print(texto)

# %%
img = cv2.imread('./Imagens/saida.jpg')
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imshow(rgb)

# %%
config_tesseract = '--tessdata-dir tessdata --psm 7'
texto = pytesseract.image_to_string(rgb, lang='por', config=config_tesseract)
print(texto)

# %% [markdown]
# ### Detecção de orientação da página

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open('./Imagens/livro01.jpg')
plt.imshow(img);

# %%
print(pytesseract.image_to_osd(img))

# %% [markdown]
# # Seleção dos textos

# %%
from pytesseract import Output

# %%
img = cv2.imread('./Imagens/teste_manuscrito_01.jpg')
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imshow(rgb)

# %% [markdown]
# - block_num = Número do bloco atual. Quando o tesseract faz o OCR, ele divide a imagem em várias regiões, o que pode variar de acordo com os parametros do PSM e também outros critérios próprios do algoritmo. Cada bloco é uma região
#
# - conf = confiança da predição (de 0 a 100. -1 significa que não foi reconhecido texto)
#
# - height = altura do bloco de texto detectada (ou seja, da caixa delimitadora)
#
# - left = coordenada x onde inicia a caixa delimitadora
#
# - level = o level (nível) corresponde à categoria do bloco detectado. são 5 valores possiveis:
#   1. página
#   2. bloco
#   3. parágrafo
#   4. linha
#   5. palavra
#
# Portanto, se foi retornado o valor 5 significa que o bloco detectado é texto, se foi 4 significa que o que foi detectado é uma linha
#
# - line_num = número da linha do que foi detectado (inicia com 0)
#
# - page_num = o índice da página onde o item foi detectado. Na maioria dos casos sempre haverá uma página só
#
# - text = o resultado do reconhecimento
#
# - top = coordenada y onde a caixa delimitadora começa
#
# - width = largura do bloco de texto atual detectado
#
# - word_num = numero da palavra (indice) dentro do bloco atual

# %%
config_tesseract = '--tessdata-dir tessdata'
resultado = pytesseract.image_to_data(rgb, config=config_tesseract, lang='por', output_type=Output.DICT)
resultado

# %%
min_conf = 40 #@param {type: 'slider', min: 0, max: 100}

# %%
def caixa_texto(resultado, img, cor = (255, 100, 0)):
  x = resultado['left'][i]
  y = resultado['top'][i]
  w = resultado['width'][i]
  h = resultado['height'][i]

  cv2.rectangle(img, (x, y), (x + w, y + h), cor, 2)

  return x, y, img

# %%
len(resultado['text'])

# %%
img_copia = rgb.copy()
for i in range(0, len(resultado['text'])):
  #print(i)
  confianca = int(resultado['conf'][i])
  #print(confianca)
  if confianca > min_conf:
    x, y, img = caixa_texto(resultado, img_copia)
    #print(x, y)
    texto = resultado['text'][i]
    cv2.putText(img_copia, texto, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 1.1, (0,0,255))
imshow(img_copia)

# %%
img = cv2.imread('./Imagens/teste02.jpg')
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
config_tesseract = "--tessdata-dir tessdata"
resultado = pytesseract.image_to_data(rgb, config=config_tesseract, lang="por", output_type=Output.DICT)
resultado

# %%
from PIL import ImageFont, ImageDraw, Image
fonte = './Fontes/calibri.ttf'

# %%
def escreve_texto(texto, x, y, img, fonte, tamanho_texto=32):
  fonte = ImageFont.truetype(fonte, tamanho_texto)
  img_pil = Image.fromarray(img)
  draw = ImageDraw.Draw(img_pil)
  draw.text((x, y - tamanho_texto), texto, font = fonte)
  img = np.array(img_pil)
  return img

# %%
img_copia = rgb.copy()
for i in range(0, len(resultado['text'])):
  confianca = int(resultado['conf'][i])
  if confianca > min_conf:
    x, y, img = caixa_texto(resultado, img_copia)
    texto = resultado['text'][i]
    # A fonte padrão do opencv FONT_HERSHEY_SIMPLEX não tem suporte para caracteres
    # com acento. Por isso usaermos a função "escreve_texto" definida na célula enterior.
    #cv2.putText(img_copia, texto, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 1.1, (0,0,255))
    img_copia = escreve_texto(texto, x, y, img_copia, fonte)
imshow(img_copia)

# %% [markdown]
# # Buscando informações específicas na imagem

# %%
import re # regular expressions

# %%
img = cv2.imread("./Imagens/tabela_teste.jpg")
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imshow(rgb)

# %%
config_tesseract = "--tessdata-dir tessdata"
resultado = pytesseract.image_to_data(rgb, config=config_tesseract, lang="por", output_type=Output.DICT)
resultado

# %%
# https://regexr.com/
padrao_data = '^(0[1-9]|[12][0-9]|3[01])/(0[1-9]|1[012])/(19|20)\d\d$'

# %%
datas = []
img_copia = rgb.copy()
for i in range(0, len(resultado['text'])):
  confianca = int(resultado['conf'][i])
  if confianca > min_conf:
    texto = resultado['text'][i]
    if re.match(padrao_data, texto):
      x, y, img = caixa_texto(resultado, img_copia, (0,0,255))
      img_copia = escreve_texto(texto, x, y, img_copia, fonte, 12)
      datas.append(texto)
    else:
      x, y, img_copia = caixa_texto(resultado, img_copia)
imshow(img_copia)

# %%
datas

# %% [markdown]
# # Detecção de texto em cenários naturais

# %%
img = cv2.imread("./Imagens/caneca.jpg")
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imshow(rgb)

# %%
config_tesseract = "--tessdata-dir tessdata --psm 11"
resultado = pytesseract.image_to_data(rgb, config=config_tesseract, lang="eng", output_type=Output.DICT)
resultado

# %%
min_conf = 50

# %%
img_copia = rgb.copy()
for i in range(0, len(resultado['text'])):
  confianca = int(resultado['conf'][i])
  if confianca > min_conf:
    texto = resultado['text'][i]
    if not texto.isspace() and len(texto) > 0:
      x, y, img = caixa_texto(resultado, img_copia)
      img_copia = escreve_texto(texto, x, y, img_copia, fonte)
imshow(img_copia)

# %%
resultado['conf']

# %%
resultado['text']
